# %%
import pickle, os 
import numpy as np 
from pathlib import Path

data_dir = Path(os.getcwd()).parent / "assets" 

with open(data_dir / "NRCB1.pickle", "rb") as f: 
    NRCB1 = pickle.load(f)
with open(data_dir / "NRCB2.pickle", "rb") as f: 
    NRCB2 = pickle.load(f) 
with open(data_dir / "NRCB3.pickle", "rb") as f: 
    NRCB3 = pickle.load(f) 
with open(data_dir / "NRCB4.pickle", "rb") as f: 
    NRCB4 = pickle.load(f)

# %%
f115w = NRCB1["mF115W"].to_numpy()
f212n = NRCB1["mF212N"].to_numpy()
f323n = NRCB1["mF323N"].to_numpy()
f405n = NRCB1["mF405N"].to_numpy()

# %%
filters = [ 
    ("F115W", "F212N", "F115W"), 
    ("F115W", "F323N", "F115W"), 
    ("F115W", "F405N", "F115W"), 
]

# %%
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

fig, axis = plt.subplots(3, 1, figsize=(8, 6))
axis = fig.add_subplot(1, 1, 1, projection='scatter_density')

for idx, (m1, m2, my) in enumerate(filters): 
    m1 = NRCB1[f"m{m1}"] 
    m2 = NRCB1[f"m{m2}"] 
    my = NRCB1[f"m{my}"] 

    mask = np.isfinite(m1) & np.isfinite(m2) 

    x = np.subtract(m1, m2)[mask]
    y = np.asarray(my)[mask]

    k = gaussian_kde([x,y])
    xi, yi = np.mgrid[
       x.min():x.max():nbins*1j,
       y.min():y.max():nbins*1j
    ]
    zi = k(np.vstack([
       xi.flatten(),
       yi.flatten()
    ])).reshape(xi.shape)


    
plt.tight_layout() 
plt.show()
