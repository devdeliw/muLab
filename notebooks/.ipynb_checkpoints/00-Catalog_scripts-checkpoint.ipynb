# %%
# 00-Fritz-slopes.ipynb

# %%
from astropy.table import Table 

catalog = Table.read("/Users/devaldeliwala/mulab/assets/jwst_init_NRCB.fits")
catalog[0:10]
# Out:
# <Table length=10>
# jwst_name_full            x             ...      y_ave_wcs        name
#    bytes22           float64[10]        ...       float64       bytes11
# -------------- ------------------------ ... ------------------- -------
#  F323N_NRCB5_1 -- .. 11.209376412898054 ...  -62.53391075265796  JWST_1
#  F323N_NRCB5_2 -- .. 115.83878153627819 ... -55.941540197817126  JWST_2
#  F323N_NRCB5_3 -- .. 137.54333975384858 ... -54.571420239273294  JWST_3
#  F323N_NRCB5_4  -- .. 423.2192380452441 ...  -36.57357409068439  JWST_4
#  F323N_NRCB5_5 -- .. 438.36416761197745 ...  -35.61538418623618  JWST_5
#  F323N_NRCB5_6  -- .. 502.4621466337746 ... -31.579598791861073  JWST_6
#  F323N_NRCB5_7  -- .. 548.9139336184994 ...  -28.65555322897749  JWST_7
#  F323N_NRCB5_8  -- .. 672.8792932206256 ... -20.842664074379194  JWST_8
#  F323N_NRCB5_9  -- .. 700.9736656350856 ... -19.065363360344946  JWST_9
# F323N_NRCB5_10  -- .. 834.1936433337144 ... -10.676374652335086 JWST_10
